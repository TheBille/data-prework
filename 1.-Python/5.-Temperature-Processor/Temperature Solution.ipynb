# %%
#section 2
points = [(4, 5), (-0, 2), (4, 7), (1, -3), (3, -2), (4, 5), (3, 2), (5, 7), (-5, 7), (2, 2), (-4, 5), (0, -2),
          (-4, 7), (-1, 3), (-3, 2), (-4, -5), (-3, 2), (5, 7), (5, 7), (2, 2), (9, 9), (-8, -9)]
## section 1
doubleshot = []
for i in range(len(points)):
    if points[i] in points[i+1:]:
        doubleshot.append(points[i])
print(set(doubleshot))

#section 2
quadrant1 = 0
quadrant2 = 0
quadrant3 = 0
quadrant4 = 0
count = 0
for x in points:
    if x[0] > 0 and x[1] > 0:
        quadrant1 += 1
    elif x[0] < 0 and x[1] > 0:
        quadrant2 += 1
    elif x[0] < 0 and x[1] < 0:
        quadrant3 += 1
    elif x[0] > 0 and x[1] < 0:
        quadrant4 += 1
print(quadrant1, "arrows will be in the first quadrant",quadrant2, "arrows will be in the second quadrant",
      quadrant3, "arrows will be in the third quadrant and", quadrant4, "will be in the fourth quadrant")

#section 3
##def nutzt man um eine Funktion zu definieren
#distance ist die die Formel d= die Wuzel aus (x2-x1)^2 (y2-y1)^2
import math
def distance(x,y):
    distance = math.sqrt((x**2)+(y**2))
    return distance


closest_point = (float('inf'),float('inf'))
closest_point_distance = 1000


temperatures_C = [33, 66, 65, 0, 59, 60, 62, 64, 70, 76, 80, 81, 80, 83, 90, 79, 61, 53, 50, 49, 53, 48, 45, 39]

#The first element of the list is the temperature at 12am, the second element is the temperature at 1am, and so on.

#The company has decided that if one of the following events occurs, then the cooling system needs to be replaced for a new one to avoid damaging the processor.

# More than 4 temperatures are greater than or equal to 70ºC.
# Any temperature is above 80ºC.
# The average temperature exceeds 65ºC.

#section 1 & 2

min_temperature = min(temperatures_C)
print(min_temperature)

max_temperature = max(temperatures_C)
print(max_temperature)

#section 3
temperatures_over70 = []

for i in temperatures_C:
    if i >70:
        temperatures_over70.append(i)
print(temperatures_over70)

#section 4

average_temperature =  sum(temperatures_C) / len(temperatures_C)
print(average_temperature)

#section 5

temperature_at_3oclock = (temperatures_C[2]+temperatures_C[4])/2

print("The temperature at 3:00 was arround",temperature_at_3oclock,"°")

#section 6

def new_cooling_system(lst):
    for x in range(len(lst)-4):
        if lst[x] >= 70 and lst[x+1] >= 70 and lst[x+2] >= 70 and lst[x+3] >= 70 and lst[x+4] >= 70:
            return True
        if lst[x] > 80:
            return True
    if (sum(lst) / len(lst)) > 65:
        return True
    else:
        return False

print(new_cooling_system(temperatures_C))
# Out:
# {(4, 5), (5, 7), (-3, 2), (2, 2)}
# 10 arrows will be in the first quadrant 6 arrows will be in the second quadrant 2 arrows will be in the third quadrant and 2 will be in the fourth quadrant
# 0
# 90
# [76, 80, 81, 80, 83, 90, 79]
# 60.25
# The temperature at 3:00 was arround 62.0 °
# True
